# %% [markdown]
# ## Visualizing What Kernel Sees
#
# This assignment focusses on using gradCAM to visualize what kernel sees to predict output

# %% [markdown]
# ### Import necessary modules

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 

from keras import regularizers
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# #### Visualzing dataset
#
# * Its very important to visualize that dataset to understand the complexity of features the network should learn
# * It also helps in understanding what sort of image augmentation should be applied to the datasets

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# #### Helper functions
#
# * Following are helper functions to understand how network performed
# * It plots graph on model accuracy and loss for training vs validation dataset over increasing epochs

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# #### Pixel Normalization
#
# * It is good to rescale dataset, so that network sees image in same range and hence makes it easy to learn

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# #### Network architecure
#
# We design the network by making the following considerations:
#   * No Dropout in last layer
#   * Remove Dense layers
#   * Have network with alternating high channels & low channels (squeeze & excite)
#   * Add Batch Normalization
#   * Add Image Normalization
#   * Add Image Augmentation

# %%
# Define the model

dropout_val = 0.15
conv_start_size = 64

def Conv_Block(model, num_channels):
  model.add(Convolution2D(num_channels, 3, 3, border_mode='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu')) 
  model.add(Dropout(dropout_val))
  model.add(Convolution2D(2*num_channels, 3, 3, border_mode='same')) 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(dropout_val))
  
def Transition_Block(model, num_channels):
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Convolution2D(num_channels, 1, 1))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(dropout_val))


model = Sequential()
model.add(Convolution2D(conv_start_size, 3, 3, border_mode='same', input_shape=(32, 32, 3))) # Output: 32x32x64
model.add(BatchNormalization())
model.add(Activation('relu')) 
model.add(Dropout(dropout_val))

Conv_Block(model, conv_start_size) # 32x32x128
Transition_Block(model, conv_start_size) # 16x16x64

Conv_Block(model, conv_start_size) # 16x16x128
Transition_Block(model, conv_start_size) # 8x8x64

Conv_Block(model, conv_start_size) # 8x8x128
Transition_Block(model, conv_start_size) # 4x4x64

Conv_Block(model, conv_start_size) # 4x4x128
Transition_Block(model, conv_start_size) # 2x2x64

model.add(Convolution2D(10, 2, 2)) # Output: 1x1x10

model.add(Flatten())
model.add(Activation('softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), input_shape=(32, 32, 3..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (2, 2))`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_29 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_30 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_31 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 16, 16, 64)        8256
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_32 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_33 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_34 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 8, 8, 64)          8256
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_35 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_36 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_37 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 4, 4, 64)          8256
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 4, 4, 64)          256
# _________________________________________________________________
# activation_38 (Activation)   (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 4, 4, 64)          36928
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 4, 4, 64)          256
# _________________________________________________________________
# activation_39 (Activation)   (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_40 (Activation)   (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 2, 2, 64)          8256
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 2, 2, 64)          256
# _________________________________________________________________
# activation_41 (Activation)   (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 2, 2, 64)          0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 1, 1, 10)          2570
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_42 (Activation)   (None, 10)                0
# =================================================================
# Total params: 484,874
# Trainable params: 482,698
# Non-trainable params: 2,176
# _________________________________________________________________

# %% [markdown]
# ### Load trained weights if you have any, rather than running the model again

# %%
import requests 
weights_url = "https://drive.google.com/uc?export=download&id=1iWJx4FiyxEZd-VAWyD8YGnrjuuPl0zFW"
  
r = requests.get(weights_url) 
  
with open("assignment_9_best_weights.hdf5",'wb') as f: 
    f.write(r.content) 

model.load_weights("assignment_9_best_weights.hdf5")

# %% [markdown]
# #### Run the  network if not trained weights available and examine output
#
# * Gives accuracy of 88.49

# %%
import numpy as np

def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(img):
        input_img = img.copy()
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %% [markdown]
# ### Visualize CutOut Image Augmentation Technique

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

cols, rows = 5, 4
img_num = cols * rows

x = train_features


eraser = get_random_eraser(v_l=0, v_h=1)
for i in range(img_num):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(eraser(x[i]), interpolation="nearest")
    plt.axis('off')

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    preprocessing_function=get_random_eraser(v_l=0, v_h=1))

checkpoint = ModelCheckpoint("assignment_9_cutout_best_weights.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 150, 
                                 validation_data = (test_features, test_labels), verbose=1,
                                 callbacks=[checkpoint])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=150)`
# W0630 12:21:00.589935 140494283507584 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/150
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 390/390 [==============================] - 37s 96ms/step - loss: 1.7816 - acc: 0.3429 - val_loss: 2.0133 - val_acc: 0.3087
#
# Epoch 00001: val_acc improved from -inf to 0.30870, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 2/150
# 390/390 [==============================] - 31s 79ms/step - loss: 1.4137 - acc: 0.4866 - val_loss: 1.6221 - val_acc: 0.4374
#
# Epoch 00002: val_acc improved from 0.30870 to 0.43740, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 3/150
# 390/390 [==============================] - 30s 77ms/step - loss: 1.1881 - acc: 0.5704 - val_loss: 1.2360 - val_acc: 0.5587
#
# Epoch 00003: val_acc improved from 0.43740 to 0.55870, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 4/150
# 390/390 [==============================] - 30s 78ms/step - loss: 1.0391 - acc: 0.6294 - val_loss: 1.2432 - val_acc: 0.5732
#
# Epoch 00004: val_acc improved from 0.55870 to 0.57320, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 5/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.9357 - acc: 0.6687 - val_loss: 1.3037 - val_acc: 0.5487
#
# Epoch 00005: val_acc did not improve from 0.57320
# Epoch 6/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.8789 - acc: 0.6894 - val_loss: 0.7791 - val_acc: 0.7317
#
# Epoch 00006: val_acc improved from 0.57320 to 0.73170, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 7/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.8270 - acc: 0.7067 - val_loss: 1.0136 - val_acc: 0.6485
#
# Epoch 00007: val_acc did not improve from 0.73170
# Epoch 8/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7985 - acc: 0.7193 - val_loss: 0.8782 - val_acc: 0.6904
#
# Epoch 00008: val_acc did not improve from 0.73170
# Epoch 9/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7589 - acc: 0.7336 - val_loss: 0.7766 - val_acc: 0.7316
#
# Epoch 00009: val_acc did not improve from 0.73170
# Epoch 10/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7336 - acc: 0.7443 - val_loss: 0.8219 - val_acc: 0.7209
#
# Epoch 00010: val_acc did not improve from 0.73170
# Epoch 11/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7104 - acc: 0.7524 - val_loss: 0.6212 - val_acc: 0.7882
#
# Epoch 00011: val_acc improved from 0.73170 to 0.78820, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 12/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.6874 - acc: 0.7619 - val_loss: 0.7937 - val_acc: 0.7291
#
# Epoch 00012: val_acc did not improve from 0.78820
# Epoch 13/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.6631 - acc: 0.7690 - val_loss: 0.7227 - val_acc: 0.7417
#
# Epoch 00013: val_acc did not improve from 0.78820
# Epoch 14/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.6538 - acc: 0.7717 - val_loss: 0.8657 - val_acc: 0.7029
#
# Epoch 00014: val_acc did not improve from 0.78820
# Epoch 15/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.6363 - acc: 0.7791 - val_loss: 0.9314 - val_acc: 0.6830
#
# Epoch 00015: val_acc did not improve from 0.78820
# Epoch 16/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.6263 - acc: 0.7817 - val_loss: 0.6050 - val_acc: 0.7956
#
# Epoch 00016: val_acc improved from 0.78820 to 0.79560, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 17/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.6074 - acc: 0.7899 - val_loss: 0.5598 - val_acc: 0.8082
#
# Epoch 00017: val_acc improved from 0.79560 to 0.80820, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 18/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5973 - acc: 0.7922 - val_loss: 0.6416 - val_acc: 0.7751
#
# Epoch 00018: val_acc did not improve from 0.80820
# Epoch 19/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5894 - acc: 0.7951 - val_loss: 0.5828 - val_acc: 0.7983
#
# Epoch 00019: val_acc did not improve from 0.80820
# Epoch 20/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5835 - acc: 0.7971 - val_loss: 0.5574 - val_acc: 0.8064
#
# Epoch 00020: val_acc did not improve from 0.80820
# Epoch 21/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5669 - acc: 0.8028 - val_loss: 0.6528 - val_acc: 0.7830
#
# Epoch 00021: val_acc did not improve from 0.80820
# Epoch 22/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5602 - acc: 0.8045 - val_loss: 0.6792 - val_acc: 0.7688
#
# Epoch 00022: val_acc did not improve from 0.80820
# Epoch 23/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5511 - acc: 0.8073 - val_loss: 0.5618 - val_acc: 0.8112
#
# Epoch 00023: val_acc improved from 0.80820 to 0.81120, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 24/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5461 - acc: 0.8099 - val_loss: 0.5460 - val_acc: 0.8095
#
# Epoch 00024: val_acc did not improve from 0.81120
# Epoch 25/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5322 - acc: 0.8161 - val_loss: 0.6052 - val_acc: 0.7886
#
# Epoch 00025: val_acc did not improve from 0.81120
# Epoch 26/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5378 - acc: 0.8143 - val_loss: 0.5316 - val_acc: 0.8217
#
# Epoch 00026: val_acc improved from 0.81120 to 0.82170, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 27/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5199 - acc: 0.8200 - val_loss: 0.4424 - val_acc: 0.8524
#
# Epoch 00027: val_acc improved from 0.82170 to 0.85240, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 28/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5184 - acc: 0.8196 - val_loss: 0.6752 - val_acc: 0.7648
#
# Epoch 00028: val_acc did not improve from 0.85240
# Epoch 29/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5096 - acc: 0.8224 - val_loss: 0.5785 - val_acc: 0.7940
#
# Epoch 00029: val_acc did not improve from 0.85240
# Epoch 30/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5098 - acc: 0.8230 - val_loss: 0.4967 - val_acc: 0.8304
#
# Epoch 00030: val_acc did not improve from 0.85240
# Epoch 31/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4950 - acc: 0.8276 - val_loss: 0.5222 - val_acc: 0.8237
#
# Epoch 00031: val_acc did not improve from 0.85240
# Epoch 32/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4853 - acc: 0.8302 - val_loss: 0.5356 - val_acc: 0.8142
#
# Epoch 00032: val_acc did not improve from 0.85240
# Epoch 33/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4859 - acc: 0.8312 - val_loss: 0.4739 - val_acc: 0.8365
#
# Epoch 00033: val_acc did not improve from 0.85240
# Epoch 34/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4803 - acc: 0.8325 - val_loss: 0.4587 - val_acc: 0.8440
#
# Epoch 00034: val_acc did not improve from 0.85240
# Epoch 35/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4750 - acc: 0.8360 - val_loss: 0.6252 - val_acc: 0.7881
#
# Epoch 00035: val_acc did not improve from 0.85240
# Epoch 36/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4711 - acc: 0.8348 - val_loss: 0.4925 - val_acc: 0.8303
#
# Epoch 00036: val_acc did not improve from 0.85240
# Epoch 37/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4699 - acc: 0.8360 - val_loss: 0.4584 - val_acc: 0.8424
#
# Epoch 00037: val_acc did not improve from 0.85240
# Epoch 38/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4678 - acc: 0.8364 - val_loss: 0.4721 - val_acc: 0.8368
#
# Epoch 00038: val_acc did not improve from 0.85240
# Epoch 39/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4587 - acc: 0.8407 - val_loss: 0.4619 - val_acc: 0.8480
#
# Epoch 00039: val_acc did not improve from 0.85240
# Epoch 40/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4596 - acc: 0.8380 - val_loss: 0.4590 - val_acc: 0.8457
#
# Epoch 00040: val_acc did not improve from 0.85240
# Epoch 41/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4427 - acc: 0.8464 - val_loss: 0.4256 - val_acc: 0.8562
#
# Epoch 00041: val_acc improved from 0.85240 to 0.85620, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 42/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4490 - acc: 0.8436 - val_loss: 0.4512 - val_acc: 0.8469
#
# Epoch 00042: val_acc did not improve from 0.85620
# Epoch 43/150
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4378 - acc: 0.8468 - val_loss: 0.5286 - val_acc: 0.8165
#
# Epoch 00043: val_acc did not improve from 0.85620
# Epoch 44/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4375 - acc: 0.8480 - val_loss: 0.5069 - val_acc: 0.8263
#
# Epoch 00044: val_acc did not improve from 0.85620
# Epoch 45/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4347 - acc: 0.8499 - val_loss: 0.4095 - val_acc: 0.8603
#
# Epoch 00045: val_acc improved from 0.85620 to 0.86030, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 46/150
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4350 - acc: 0.8487 - val_loss: 0.4495 - val_acc: 0.8431
#
# Epoch 00046: val_acc did not improve from 0.86030
# Epoch 47/150
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4312 - acc: 0.8498 - val_loss: 0.4146 - val_acc: 0.8610
#
# Epoch 00047: val_acc improved from 0.86030 to 0.86100, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 48/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4315 - acc: 0.8494 - val_loss: 0.4391 - val_acc: 0.8474
#
# Epoch 00048: val_acc did not improve from 0.86100
# Epoch 49/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4229 - acc: 0.8525 - val_loss: 0.4129 - val_acc: 0.8576
#
# Epoch 00049: val_acc did not improve from 0.86100
# Epoch 50/150
# 390/390 [==============================] - 30s 78ms/step - loss: 0.4237 - acc: 0.8535 - val_loss: 0.5050 - val_acc: 0.8277
#
# Epoch 00050: val_acc did not improve from 0.86100
# Epoch 51/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4170 - acc: 0.8551 - val_loss: 0.3588 - val_acc: 0.8795
#
# Epoch 00051: val_acc improved from 0.86100 to 0.87950, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 52/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4175 - acc: 0.8541 - val_loss: 0.4217 - val_acc: 0.8591
#
# Epoch 00052: val_acc did not improve from 0.87950
# Epoch 53/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4165 - acc: 0.8551 - val_loss: 0.4248 - val_acc: 0.8549
#
# Epoch 00053: val_acc did not improve from 0.87950
# Epoch 54/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4134 - acc: 0.8554 - val_loss: 0.4979 - val_acc: 0.8251
#
# Epoch 00054: val_acc did not improve from 0.87950
# Epoch 55/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4083 - acc: 0.8573 - val_loss: 0.4202 - val_acc: 0.8585
#
# Epoch 00055: val_acc did not improve from 0.87950
# Epoch 56/150
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4024 - acc: 0.8595 - val_loss: 0.4145 - val_acc: 0.8600
#
# Epoch 00056: val_acc did not improve from 0.87950
# Epoch 57/150
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4092 - acc: 0.8571 - val_loss: 0.5619 - val_acc: 0.8086
#
# Epoch 00057: val_acc did not improve from 0.87950
# Epoch 58/150
# 390/390 [==============================] - 31s 78ms/step - loss: 0.3994 - acc: 0.8605 - val_loss: 0.5318 - val_acc: 0.8181
#
# Epoch 00058: val_acc did not improve from 0.87950
# Epoch 59/150
# 390/390 [==============================] - 31s 78ms/step - loss: 0.3937 - acc: 0.8613 - val_loss: 0.3779 - val_acc: 0.8693
#
# Epoch 00059: val_acc did not improve from 0.87950
# Epoch 60/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3941 - acc: 0.8621 - val_loss: 0.4772 - val_acc: 0.8393
#
# Epoch 00060: val_acc did not improve from 0.87950
# Epoch 61/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3927 - acc: 0.8626 - val_loss: 0.3807 - val_acc: 0.8685
#
# Epoch 00061: val_acc did not improve from 0.87950
# Epoch 62/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3839 - acc: 0.8676 - val_loss: 0.4458 - val_acc: 0.8454
#
# Epoch 00062: val_acc did not improve from 0.87950
# Epoch 63/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3889 - acc: 0.8643 - val_loss: 0.3784 - val_acc: 0.8721
#
# Epoch 00063: val_acc did not improve from 0.87950
# Epoch 64/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3850 - acc: 0.8642 - val_loss: 0.4066 - val_acc: 0.8614
#
# Epoch 00064: val_acc did not improve from 0.87950
# Epoch 65/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3890 - acc: 0.8638 - val_loss: 0.3909 - val_acc: 0.8644
#
# Epoch 00065: val_acc did not improve from 0.87950
# Epoch 66/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3865 - acc: 0.8654 - val_loss: 0.4519 - val_acc: 0.8456
#
# Epoch 00066: val_acc did not improve from 0.87950
# Epoch 67/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3809 - acc: 0.8670 - val_loss: 0.3717 - val_acc: 0.8722
#
# Epoch 00067: val_acc did not improve from 0.87950
# Epoch 68/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3831 - acc: 0.8659 - val_loss: 0.3693 - val_acc: 0.8756
#
# Epoch 00068: val_acc did not improve from 0.87950
# Epoch 69/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3812 - acc: 0.8666 - val_loss: 0.3819 - val_acc: 0.8672
#
# Epoch 00069: val_acc did not improve from 0.87950
# Epoch 70/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3814 - acc: 0.8674 - val_loss: 0.4733 - val_acc: 0.8395
#
# Epoch 00070: val_acc did not improve from 0.87950
# Epoch 71/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3733 - acc: 0.8701 - val_loss: 0.4068 - val_acc: 0.8589
#
# Epoch 00071: val_acc did not improve from 0.87950
# Epoch 72/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3705 - acc: 0.8693 - val_loss: 0.5164 - val_acc: 0.8290
#
# Epoch 00072: val_acc did not improve from 0.87950
# Epoch 73/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3709 - acc: 0.8709 - val_loss: 0.4978 - val_acc: 0.8336
#
# Epoch 00073: val_acc did not improve from 0.87950
# Epoch 74/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3731 - acc: 0.8698 - val_loss: 0.4393 - val_acc: 0.8521
#
# Epoch 00074: val_acc did not improve from 0.87950
# Epoch 75/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3687 - acc: 0.8713 - val_loss: 0.3749 - val_acc: 0.8717
#
# Epoch 00075: val_acc did not improve from 0.87950
# Epoch 76/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3668 - acc: 0.8718 - val_loss: 0.4295 - val_acc: 0.8506
#
# Epoch 00076: val_acc did not improve from 0.87950
# Epoch 77/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3609 - acc: 0.8745 - val_loss: 0.4329 - val_acc: 0.8537
#
# Epoch 00077: val_acc did not improve from 0.87950
# Epoch 78/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3665 - acc: 0.8734 - val_loss: 0.4487 - val_acc: 0.8477
#
# Epoch 00078: val_acc did not improve from 0.87950
# Epoch 79/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3677 - acc: 0.8723 - val_loss: 0.3443 - val_acc: 0.8827
#
# Epoch 00079: val_acc improved from 0.87950 to 0.88270, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 80/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3526 - acc: 0.8773 - val_loss: 0.4365 - val_acc: 0.8495
#
# Epoch 00080: val_acc did not improve from 0.88270
# Epoch 81/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3556 - acc: 0.8760 - val_loss: 0.3389 - val_acc: 0.8840
#
# Epoch 00081: val_acc improved from 0.88270 to 0.88400, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 82/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3558 - acc: 0.8752 - val_loss: 0.4001 - val_acc: 0.8654
#
# Epoch 00082: val_acc did not improve from 0.88400
# Epoch 83/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3559 - acc: 0.8755 - val_loss: 0.4420 - val_acc: 0.8502
#
# Epoch 00083: val_acc did not improve from 0.88400
# Epoch 84/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3611 - acc: 0.8746 - val_loss: 0.4523 - val_acc: 0.8479
#
# Epoch 00084: val_acc did not improve from 0.88400
# Epoch 85/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3499 - acc: 0.8788 - val_loss: 0.4956 - val_acc: 0.8328
#
# Epoch 00085: val_acc did not improve from 0.88400
# Epoch 86/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3577 - acc: 0.8761 - val_loss: 0.3645 - val_acc: 0.8742
#
# Epoch 00086: val_acc did not improve from 0.88400
# Epoch 87/150
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3554 - acc: 0.8759 - val_loss: 0.3669 - val_acc: 0.8730
#
# Epoch 00087: val_acc did not improve from 0.88400
# Epoch 88/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3543 - acc: 0.8777 - val_loss: 0.3843 - val_acc: 0.8687
#
# Epoch 00088: val_acc did not improve from 0.88400
# Epoch 89/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3483 - acc: 0.8782 - val_loss: 0.3384 - val_acc: 0.8851
#
# Epoch 00089: val_acc improved from 0.88400 to 0.88510, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 90/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3457 - acc: 0.8798 - val_loss: 0.3574 - val_acc: 0.8756
#
# Epoch 00090: val_acc did not improve from 0.88510
# Epoch 91/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3466 - acc: 0.8784 - val_loss: 0.3984 - val_acc: 0.8675
#
# Epoch 00091: val_acc did not improve from 0.88510
# Epoch 92/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3444 - acc: 0.8789 - val_loss: 0.4133 - val_acc: 0.8588
#
# Epoch 00092: val_acc did not improve from 0.88510
# Epoch 93/150
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3437 - acc: 0.8784 - val_loss: 0.4048 - val_acc: 0.8615
#
# Epoch 00093: val_acc did not improve from 0.88510
# Epoch 94/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3421 - acc: 0.8808 - val_loss: 0.3806 - val_acc: 0.8675
#
# Epoch 00094: val_acc did not improve from 0.88510
# Epoch 95/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3447 - acc: 0.8817 - val_loss: 0.4567 - val_acc: 0.8469
#
# Epoch 00095: val_acc did not improve from 0.88510
# Epoch 96/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3428 - acc: 0.8794 - val_loss: 0.3712 - val_acc: 0.8750
#
# Epoch 00096: val_acc did not improve from 0.88510
# Epoch 97/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3394 - acc: 0.8816 - val_loss: 0.3351 - val_acc: 0.8855
#
# Epoch 00097: val_acc improved from 0.88510 to 0.88550, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 98/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3409 - acc: 0.8802 - val_loss: 0.3413 - val_acc: 0.8804
#
# Epoch 00098: val_acc did not improve from 0.88550
# Epoch 99/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3378 - acc: 0.8818 - val_loss: 0.4438 - val_acc: 0.8519
#
# Epoch 00099: val_acc did not improve from 0.88550
# Epoch 100/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3379 - acc: 0.8815 - val_loss: 0.3467 - val_acc: 0.8839
#
# Epoch 00100: val_acc did not improve from 0.88550
# Epoch 101/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3372 - acc: 0.8831 - val_loss: 0.3391 - val_acc: 0.8861
#
# Epoch 00101: val_acc improved from 0.88550 to 0.88610, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 102/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3300 - acc: 0.8853 - val_loss: 0.3383 - val_acc: 0.8818
#
# Epoch 00102: val_acc did not improve from 0.88610
# Epoch 103/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3344 - acc: 0.8834 - val_loss: 0.3832 - val_acc: 0.8697
#
# Epoch 00103: val_acc did not improve from 0.88610
# Epoch 104/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3336 - acc: 0.8828 - val_loss: 0.3168 - val_acc: 0.8911
#
# Epoch 00104: val_acc improved from 0.88610 to 0.89110, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 105/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3299 - acc: 0.8843 - val_loss: 0.3679 - val_acc: 0.8761
#
# Epoch 00105: val_acc did not improve from 0.89110
# Epoch 106/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3271 - acc: 0.8851 - val_loss: 0.3901 - val_acc: 0.8668
#
# Epoch 00106: val_acc did not improve from 0.89110
# Epoch 107/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3284 - acc: 0.8854 - val_loss: 0.3364 - val_acc: 0.8891
#
# Epoch 00107: val_acc did not improve from 0.89110
# Epoch 108/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3304 - acc: 0.8832 - val_loss: 0.3361 - val_acc: 0.8835
#
# Epoch 00108: val_acc did not improve from 0.89110
# Epoch 109/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3259 - acc: 0.8859 - val_loss: 0.3506 - val_acc: 0.8817
#
# Epoch 00109: val_acc did not improve from 0.89110
# Epoch 110/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3235 - acc: 0.8871 - val_loss: 0.3430 - val_acc: 0.8856
#
# Epoch 00110: val_acc did not improve from 0.89110
# Epoch 111/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3341 - acc: 0.8839 - val_loss: 0.4261 - val_acc: 0.8517
#
# Epoch 00111: val_acc did not improve from 0.89110
# Epoch 112/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3223 - acc: 0.8876 - val_loss: 0.3108 - val_acc: 0.8958
#
# Epoch 00112: val_acc improved from 0.89110 to 0.89580, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 113/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3231 - acc: 0.8856 - val_loss: 0.3902 - val_acc: 0.8667
#
# Epoch 00113: val_acc did not improve from 0.89580
# Epoch 114/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3240 - acc: 0.8857 - val_loss: 0.3533 - val_acc: 0.8803
#
# Epoch 00114: val_acc did not improve from 0.89580
# Epoch 115/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3231 - acc: 0.8871 - val_loss: 0.3445 - val_acc: 0.8814
#
# Epoch 00115: val_acc did not improve from 0.89580
# Epoch 116/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3217 - acc: 0.8880 - val_loss: 0.3618 - val_acc: 0.8754
#
# Epoch 00116: val_acc did not improve from 0.89580
# Epoch 117/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3231 - acc: 0.8871 - val_loss: 0.3827 - val_acc: 0.8728
#
# Epoch 00117: val_acc did not improve from 0.89580
# Epoch 118/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3191 - acc: 0.8889 - val_loss: 0.3548 - val_acc: 0.8809
#
# Epoch 00118: val_acc did not improve from 0.89580
# Epoch 119/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3197 - acc: 0.8882 - val_loss: 0.2868 - val_acc: 0.9024
#
# Epoch 00119: val_acc improved from 0.89580 to 0.90240, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 120/150
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3114 - acc: 0.8912 - val_loss: 0.3044 - val_acc: 0.8956
#
# Epoch 00120: val_acc did not improve from 0.90240
# Epoch 121/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3191 - acc: 0.8893 - val_loss: 0.3627 - val_acc: 0.8793
#
# Epoch 00121: val_acc did not improve from 0.90240
# Epoch 122/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3196 - acc: 0.8881 - val_loss: 0.3331 - val_acc: 0.8886
#
# Epoch 00122: val_acc did not improve from 0.90240
# Epoch 123/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3206 - acc: 0.8866 - val_loss: 0.3355 - val_acc: 0.8843
#
# Epoch 00123: val_acc did not improve from 0.90240
# Epoch 124/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3157 - acc: 0.8888 - val_loss: 0.3353 - val_acc: 0.8880
#
# Epoch 00124: val_acc did not improve from 0.90240
# Epoch 125/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3127 - acc: 0.8903 - val_loss: 0.3661 - val_acc: 0.8734
#
# Epoch 00125: val_acc did not improve from 0.90240
# Epoch 126/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3115 - acc: 0.8904 - val_loss: 0.3408 - val_acc: 0.8866
#
# Epoch 00126: val_acc did not improve from 0.90240
# Epoch 127/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3114 - acc: 0.8917 - val_loss: 0.3228 - val_acc: 0.8884
#
# Epoch 00127: val_acc did not improve from 0.90240
# Epoch 128/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3090 - acc: 0.8916 - val_loss: 0.3866 - val_acc: 0.8706
#
# Epoch 00128: val_acc did not improve from 0.90240
# Epoch 129/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3093 - acc: 0.8905 - val_loss: 0.3160 - val_acc: 0.8920
#
# Epoch 00129: val_acc did not improve from 0.90240
# Epoch 130/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3103 - acc: 0.8915 - val_loss: 0.3049 - val_acc: 0.8976
#
# Epoch 00130: val_acc did not improve from 0.90240
# Epoch 131/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3078 - acc: 0.8920 - val_loss: 0.3690 - val_acc: 0.8767
#
# Epoch 00131: val_acc did not improve from 0.90240
# Epoch 132/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3111 - acc: 0.8914 - val_loss: 0.3309 - val_acc: 0.8886
#
# Epoch 00132: val_acc did not improve from 0.90240
# Epoch 133/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3120 - acc: 0.8912 - val_loss: 0.3781 - val_acc: 0.8715
#
# Epoch 00133: val_acc did not improve from 0.90240
# Epoch 134/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3007 - acc: 0.8949 - val_loss: 0.3070 - val_acc: 0.8975
#
# Epoch 00134: val_acc did not improve from 0.90240
# Epoch 135/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3085 - acc: 0.8917 - val_loss: 0.3243 - val_acc: 0.8928
#
# Epoch 00135: val_acc did not improve from 0.90240
# Epoch 136/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3070 - acc: 0.8932 - val_loss: 0.3257 - val_acc: 0.8882
#
# Epoch 00136: val_acc did not improve from 0.90240
# Epoch 137/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3047 - acc: 0.8929 - val_loss: 0.3037 - val_acc: 0.8961
#
# Epoch 00137: val_acc did not improve from 0.90240
# Epoch 138/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3073 - acc: 0.8921 - val_loss: 0.3367 - val_acc: 0.8842
#
# Epoch 00138: val_acc did not improve from 0.90240
# Epoch 139/150
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3041 - acc: 0.8952 - val_loss: 0.2796 - val_acc: 0.9052
#
# Epoch 00139: val_acc improved from 0.90240 to 0.90520, saving model to assignment_9_cutout_best_weights.hdf5
# Epoch 140/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3038 - acc: 0.8931 - val_loss: 0.3653 - val_acc: 0.8771
#
# Epoch 00140: val_acc did not improve from 0.90520
# Epoch 141/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3058 - acc: 0.8927 - val_loss: 0.3101 - val_acc: 0.8974
#
# Epoch 00141: val_acc did not improve from 0.90520
# Epoch 142/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3010 - acc: 0.8941 - val_loss: 0.2915 - val_acc: 0.9000
#
# Epoch 00142: val_acc did not improve from 0.90520
# Epoch 143/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3040 - acc: 0.8935 - val_loss: 0.3321 - val_acc: 0.8870
#
# Epoch 00143: val_acc did not improve from 0.90520
# Epoch 144/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2953 - acc: 0.8978 - val_loss: 0.2951 - val_acc: 0.8969
#
# Epoch 00144: val_acc did not improve from 0.90520
# Epoch 145/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2998 - acc: 0.8939 - val_loss: 0.3416 - val_acc: 0.8815
#
# Epoch 00145: val_acc did not improve from 0.90520
# Epoch 146/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2967 - acc: 0.8963 - val_loss: 0.3462 - val_acc: 0.8808
#
# Epoch 00146: val_acc did not improve from 0.90520
# Epoch 147/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3036 - acc: 0.8930 - val_loss: 0.3131 - val_acc: 0.8897
#
# Epoch 00147: val_acc did not improve from 0.90520
# Epoch 148/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3024 - acc: 0.8945 - val_loss: 0.2981 - val_acc: 0.8969
#
# Epoch 00148: val_acc did not improve from 0.90520
# Epoch 149/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2935 - acc: 0.8971 - val_loss: 0.3872 - val_acc: 0.8684
#
# Epoch 00149: val_acc did not improve from 0.90520
# Epoch 150/150
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2961 - acc: 0.8956 - val_loss: 0.3239 - val_acc: 0.8887
#
# Epoch 00150: val_acc did not improve from 0.90520
# Model took 4523.83 seconds to train
# Accuracy on test data is: 88.87

# %% [markdown]
# ### Save the model weights
# * Better to save the model weights
# * Following downloads it to your local computer
# * You can upload it to Google Drive and give downloadable link

# %%
from google.colab import files
files.download("assignment_9_cutout_best_weights.hdf5")

# %% [markdown]
# ### gradCAM to visualize Class Activation Maps

# %%
import cv2
import keras.backend as K

def gradCAM(model, img, layer_name):
    # expand axis so that it can be passed as input to model
    # i.e from 32x32x3 -> 1x32x32x3
    x = np.expand_dims(img, axis=0)
    
    # Fetch top prediction of the image
    # Also fetch output from last convolution layer
    # Resulting feature map will be of shape same as layer's kernel shape
    preds = model.predict(x)
    class_idx = np.argmax(preds[0])
    class_output = model.output[:, class_idx]
    last_conv_layer = model.get_layer(layer_name)
   
    # Fetch gradient from last layer
    grads = K.gradients(class_output, last_conv_layer.output)[0]
    
    # Perform Global Average Pooling (GAP)
    pooled_grads = K.mean(grads, axis=(0, 1, 2))
    
    # Iterate through all channels and merge them
    iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
    pooled_grads_value, conv_layer_output_value = iterate([x])
    for i in range(last_conv_layer.kernel.shape[-1]):
        conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

    # Average the feature maps along channel dimension resulting in
    # heatmp of size same as kernel size of layer in consideration
    heatmap = np.mean(conv_layer_output_value, axis=-1)
    heatmap = np.maximum(heatmap, 0)
    
    # Normalize heatmap
    heatmap /= np.max(heatmap)

    # Resize heatmap to match image shape
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    # Generate heatmap
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    # Superimpose heatmap onto image
    superimposed_img = cv2.addWeighted(np.uint8(255 * img), 0.6, heatmap, 0.4, 0)
 
    return superimposed_img

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# Layers of which CAM is required
conv_layers = ["conv2d_39", "conv2d_40", "conv2d_41", "conv2d_42"]
# Number of images to be used in visualization
num_images = 4


fig=plt.figure(figsize=(14, 14))
columns = 1 + len(conv_layers)
rows = num_images

# Pick same 4 images from Assignment 9A
img_id = 27028 # np.random.randint(train_features.shape[0] - num_images)

placeHolderId = 0
while placeHolderId < rows*columns:
    # Original Image
    placeHolderId += 1
    fig.add_subplot(rows, columns, placeHolderId)
    img = train_features[img_id]
    plt.imshow(img)
    annotation = "Image ID: " + str(img_id)
    plt.annotate(annotation, xy=(0,0), xytext=(0,-1.2), fontsize=10)
    
    for layer_name in conv_layers:
      # gradCAM Imposed Image
      placeHolderId += 1
      superimposed_img = gradCAM(model, img, layer_name)
      fig.add_subplot(rows, columns, placeHolderId)
      plt.imshow(superimposed_img)
      annotation = layer_name + " (with CAM)"
      plt.annotate(annotation, xy=(0,0), xytext=(0,-1.2), fontsize=10)

    img_id += 1

plt.show()
